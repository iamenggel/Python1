# %%
import pandas as pd
#tabela foi importada do google drive. icon (Pasta)>drive>Mydrive>>Imersão Python>dados_experimentos(copiarcaminho- clique direito)
dados=pd.read_csv('/content/drive/MyDrive/Imersão Python/dados_experimentos.csv')
dados
# Out:
#                  id    tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 0      id_000644bb2     com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1      id_000779bfc     com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2      id_000a6266a     com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 3      id_0015fd391     com_droga     48   D1  ... -1.6210 -0.8784 -0.3876 -0.8154
# 4      id_001626bd3     com_droga     72   D2  ...  0.1094  0.2885 -0.3786  0.7125
# ...             ...           ...    ...  ...  ...     ...     ...     ...     ...
# 23809  id_fffb1ceed     com_droga     24   D2  ...  0.0631  0.9171  0.5258  0.4680
# 23810  id_fffb70c0c     com_droga     24   D2  ... -0.2084 -0.1224 -0.2715  0.3689
# 23811  id_fffc1c3f4  com_controle     48   D2  ...  0.2256  0.7592  0.6656  0.3808
# 23812  id_fffcb9e7c     com_droga     24   D1  ...  0.1732  0.7015 -0.6290  0.0740
# ...

# %%
dados.shape
#(linhas,colunas)
# Out:
# (23814, 877)

# %% [markdown]
# # Visualizar só uma coluna

# %%
dados['tratamento']
# Out:
# 0           com_droga
# 1           com_droga
# 2           com_droga
# 3           com_droga
# 4           com_droga
#              ...
# 23809       com_droga
# 23810       com_droga
# 23811    com_controle
# 23812       com_droga
# 23813       com_droga
# Name: tratamento, Length: 23814, dtype: object

# %%
dados['tratamento'].unique() #categorias dentro da variável
# Out:
# array(['com_droga', 'com_controle'], dtype=object)

# %%
dados['tempo'].unique()
# Out:
# array([24, 72, 48])

# %%
dados['dose'].unique()
# Out:
# array(['D1', 'D2'], dtype=object)

# %%
dados['droga'].unique()
# Out:
# array(['b68db1d53', 'df89a8e5a', '18bb41b2c', ..., '573c787a2',
#        'b2fe3eca7', 'dd4a96d16'], dtype=object)

# %%
dados['g-0'].unique() # g está representando a abreviação de gene. E os resultados são a expressão resposta do gene ao recebimento/ ou não da droga
# Out:
# array([ 1.062 ,  0.0743,  0.628 , ...,  0.3942,  0.666 , -0.8598])

# %%
lista=[1,2,3,4]
lista[3]
#A lista começa com 0
# Out:
# 4

# %%
dados['tratamento'].value_counts() #aspas simples e duplas não tem diferença. mas definaum padrão
# Out:
# com_droga       21948
# com_controle     1866
# Name: tratamento, dtype: int64

# %%
#Proporção das classes tratamento
dados['tratamento'].value_counts(normalize= True)
# Out:
# com_droga       0.921643
# com_controle    0.078357
# Name: tratamento, dtype: float64

# %%
dados['dose'].value_counts()
dados['dose'].value_counts(normalize= True)
# Out:
# D1    0.510078
# D2    0.489922
# Name: dose, dtype: float64

# %%
dados['tratamento'].value_counts().plot.pie()

# %%
dados['tempo'].value_counts().plot.pie()

# %%
dados['tempo'].value_counts().plot.bar()

# %%
#selecionar elemenos maiores que 0
dados_filtrados=dados[dados['g-0']>0]
dados_filtrados.head()
# Out:
#              id tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 0  id_000644bb2  com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1  id_000779bfc  com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2  id_000a6266a  com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 6  id_001bd861f  com_droga     24   D2  ...  2.4670  0.0357  0.1351 -0.3179
# 7  id_0020d0484  com_droga     48   D1  ...  0.6633  0.4562 -0.9622  0.0260
#
# [5 rows x 877 columns]

# %%
#seaborn =biblioteca de visualização de dados
#modificar o nome da coluna drogas

mapa = {'droga': 'composto'}
dados.rename(columns=mapa, inplace=True)

# %%
#cuidado que os códicgos de cima não vão mais funcionar, pela renomeação
dados.head()
# Out:
#              id tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 0  id_000644bb2  com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1  id_000779bfc  com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2  id_000a6266a  com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 3  id_0015fd391  com_droga     48   D1  ... -1.6210 -0.8784 -0.3876 -0.8154
# 4  id_001626bd3  com_droga     72   D2  ...  0.1094  0.2885 -0.3786  0.7125
#
# [5 rows x 877 columns]

# %%
import seaborn as sns
#aumentar o tamanho da imagem
import matplotlib.pyplot as plt
#salva as configurações de imagem do seaburn
sns.set()

# %%
#descobrir as 5 drogas/composto com maior frequencia
cod_compostos = dados['composto'].value_counts().index[:5]
cod_compostos

#filtro pra selecionar o que queremos
dados.query('composto in @cod_compostos')

plt.figure(figsize=(10,8))
# contar os dados para plotar a informação
sns.countplot(x= 'composto', data=dados.query('composto in @cod_compostos'))

# %%
# contar os dados para plotar a informação
# @ na query= seleciona informação ver no pandas
ax = sns.countplot(x= 'composto', data=dados.query('composto in @cod_compostos'))
ax.set_title('Top 5 compostos')
plt.show()

# %%
#quantos elementos eu tenho no g0
dados['g-0'].unique()
len(dados['g-0'].unique())
# Out:
# 14367

# %% [markdown]
# Desafio : ordenar o countplot depois do seaburn

# %%
dados['g-0'].min()
# Out:
# -5.513

# %%
dados['g-0'].max()
# Out:
# 10.0

# %%
dados['g-0'].hist()

# %%
#visualizar melhor o comportamento dos dados, reduzir o intervalo
dados['g-0'].hist(bins=100)
#formato da curva de distribuição (parece normal)

# %%
dados['g-19'].hist(bins=100)

# %% [markdown]
# Função do pandas da análise descritiva

# %%
dados.describe()
# Out:
#               tempo           g-0  ...          c-98          c-99
# count  23814.000000  23814.000000  ...  23814.000000  23814.000000
# mean      48.020156      0.248366  ...     -0.470252     -0.301505
# std       19.402807      1.393399  ...      1.834828      1.407918
# min       24.000000     -5.513000  ...    -10.000000    -10.000000
# 25%       24.000000     -0.473075  ...     -0.592600     -0.562900
# 50%       48.000000     -0.008850  ...      0.014000     -0.019500
# 75%       72.000000      0.525700  ...      0.461275      0.438650
# max       72.000000     10.000000  ...      3.111000      3.805000
#
# [8 rows x 873 columns]

# %%
#lista com nomes de elementos
#g0 e g1

#linha que eu quero selecionar e coluna, só os g
dados.loc[:,'g-0':'g-771'].describe().T

# histograma pra minhas médias dos genes
# .T transformar linhas e colunas e colunas em linha
# Out:
#          count      mean       std     min       25%      50%       75%     max
# g-0    23814.0  0.248366  1.393399  -5.513 -0.473075 -0.00885  0.525700  10.000
# g-1    23814.0 -0.095684  0.812363  -5.737 -0.562200 -0.04660  0.403075   5.039
# g-2    23814.0  0.152253  1.035731  -9.104 -0.437750  0.07520  0.663925   8.257
# g-3    23814.0  0.081971  0.950012  -5.998 -0.429575  0.00805  0.463400  10.000
# g-4    23814.0  0.057347  1.032091  -6.369 -0.470925 -0.02690  0.465375  10.000
# ...        ...       ...       ...     ...       ...      ...       ...     ...
# g-767  23814.0 -0.076251  1.115477 -10.000 -0.506200  0.00990  0.511175   6.317
# g-768  23814.0  0.134162  0.951264  -4.269 -0.353100  0.00540  0.409075  10.000
# g-769  23814.0 -0.128018  1.230636 -10.000 -0.544600  0.00060  0.498500   5.911
# g-770  23814.0 -0.219210  1.326193 -10.000 -0.554400  0.02870  0.496400  10.000
# g-771  23814.0  0.101524  1.417674 -10.000 -0.523800 -0.00650  0.536950  10.000
#
# ...

# %%
dados.loc[:,'g-0':'g-771'].describe().T['mean'].hist(bins=50)

# %%
dados.loc[:,'g-0':'g-771'].describe().T['min'].hist(bins=50)

# %%
dados.loc[:,'c-0':'c-99'].describe().T['mean'].hist(bins=50)

# %%
#boxplot com seaburn
sns.boxplot(x='g-0', data=dados)

# %%
sns.boxplot(x='g-0', y="tratamento", data=dados)

# %%
plt.figure(figsize= (10,8))
sns.boxplot(y='g-0', x="tratamento", data=dados)

# %%
dados.head()
#lembrar que estamos trabalhando com pandas procurar funçoes na biblioteca
# Out:
#              id tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 0  id_000644bb2  com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1  id_000779bfc  com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2  id_000a6266a  com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 3  id_0015fd391  com_droga     48   D1  ... -1.6210 -0.8784 -0.3876 -0.8154
# 4  id_001626bd3  com_droga     72   D2  ...  0.1094  0.2885 -0.3786  0.7125
#
# [5 rows x 877 columns]

# %%
#crosstab cruza nossas informações com um parâmetro de frequência
pd.crosstab(dados['dose'], dados ['tempo']) 
#mistura de com comosto e sem composto
# Out:
# tempo    24    48    72
# dose
# D1     3886  4354  3907
# D2     3886  3896  3885

# %%
pd.crosstab([dados['dose'], dados ['tempo']], dados['tratamento'])
# Out:
# tratamento  com_controle  com_droga
# dose tempo
# D1   24              301       3585
#      48              343       4011
#      72              307       3600
# D2   24              305       3581
#      48              305       3591
#      72              305       3580

# %%
pd.crosstab([dados['dose'], dados ['tempo']], dados['tratamento'], normalize = True)
# Out:
# tratamento  com_controle  com_droga
# dose tempo
# D1   24         0.012640   0.150542
#      48         0.014403   0.168430
#      72         0.012892   0.151172
# D2   24         0.012808   0.150374
#      48         0.012808   0.150794
#      72         0.012808   0.150332

# %%
pd.crosstab([dados['dose'], dados ['tempo']], dados['tratamento'], normalize = 'index')
#considera o total pra calcular a proporção, a soma de cada uma das linhas
# Out:
# tratamento  com_controle  com_droga
# dose tempo
# D1   24         0.077458   0.922542
#      48         0.078778   0.921222
#      72         0.078577   0.921423
# D2   24         0.078487   0.921513
#      48         0.078285   0.921715
#      72         0.078507   0.921493

# %%
pd.crosstab([dados['dose'], dados ['tempo']], dados['tratamento'], values=dados['g-0'], aggfunc='mean')
#um valor/gene especifico
# Out:
# tratamento  com_controle  com_droga
# dose tempo
# D1   24        -0.251760   0.367996
#      48        -0.122773   0.412469
#      72        -0.295271   0.286250
# D2   24         0.010754   0.115253
#      48         0.013174   0.214480
#      72         0.070250   0.253439

# %%
dados[['g-0','g-3']]
#relação do x0 e x3
sns.scatterplot(x='g-0', y='g-3', data=dados)
#scatterplot gráfico de dispersão

# %%
dados[['g-0','g-3']]
# Out:
#           g-0     g-3
# 0      1.0620 -0.6208
# 1      0.0743  0.0604
# 2      0.6280 -0.0764
# 3     -0.5138  0.5288
# 4     -0.3254  0.6919
# ...       ...     ...
# 23809  0.1394 -0.5080
# 23810 -1.3260  0.9905
# 23811  0.3942 -0.7389
# 23812  0.6660  0.2044
# 23813 -0.8598  0.7952
#
# [23814 rows x 2 columns]

# %%
dados[['g-0','g-8']]
#relação do x0 e x3
sns.scatterplot(x='g-0', y='g-8', data=dados)
#scatterplot gráfico de dispersão

# %%
sns.lmplot(data=dados, x='g-0', y='g-8', line_kws={'color':'red'})
#gráfico com linha de tendência dos dados
#line=parâmetro que quer alterar (cor)

# %%
sns.lmplot(data=dados, x='g-0', y='g-8', line_kws={'color':'red'}, col='tratamento')

# %%
sns.lmplot(data=dados, x='g-0', y='g-8', line_kws={'color':'red'}, col='tratamento', row ='tempo')

# %%
#calcular a correlação entre as variáveis/genes

dados.loc[:,'g-0':'g-771'].corr()

#correlações negativas e pá
#ele explica o que é correlação (taxas de correlações)
# Out:
#             g-0       g-1       g-2  ...     g-769     g-770     g-771
# g-0    1.000000  0.086032  0.176188  ... -0.127375 -0.514201  0.405908
# g-1    0.086032  1.000000 -0.054518  ... -0.006866 -0.095108 -0.032233
# g-2    0.176188 -0.054518  1.000000  ...  0.014489 -0.078661  0.103985
# g-3    0.011266 -0.027855  0.042633  ... -0.206077 -0.002142  0.058219
# g-4    0.403153  0.193647  0.013968  ... -0.172727 -0.363673  0.250713
# ...         ...       ...       ...  ...       ...       ...       ...
# g-767 -0.052622 -0.003378 -0.053149  ...  0.065450  0.008603 -0.001136
# g-768  0.300241 -0.030756  0.115415  ...  0.079364 -0.382607  0.351651
# g-769 -0.127375 -0.006866  0.014489  ...  1.000000  0.135853 -0.083713
# g-770 -0.514201 -0.095108 -0.078661  ...  0.135853  1.000000 -0.425063
# g-771  0.405908 -0.032233  0.103985  ... -0.083713 -0.425063  1.000000
#
# [772 rows x 772 columns]

# %%
# Código que gera a matriz de correlação
#reduziu pro g-50
#np biblioteca numpy
import numpy as np
corr = dados.loc[:,'g-0':'g-50'].corr()

# Generate a mask for the upper triangle
mask = np.triu(np.ones_like(corr, dtype=bool))

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(11, 9))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(230, 20, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr, mask=mask, cmap=cmap, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})
#mostra efeitos nos genes mais correlacionados, mas não implica causalidade, um gene pode não está tendo efeito sobre o outro

# %% [markdown]
# Correlação X Causalidade

# %%
corr_celular= dados.loc[:,'c-0':'c-50'].corr()
#c é a viabilidade, quanto as células de cada tipo sobreviveram a partir da aplicação do composto (tratamento)
 
# Generate a mask for the upper triangle
mask = np.triu(np.ones_like(corr_celular, dtype=bool))

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(11, 9))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(230, 20, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr_celular, mask=mask, cmap=cmap, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})

# %%
# Aula 4
# Base de dados resultados
dados_resultados = pd.read_csv('https://github.com/iamenggel/Python1/blob/main/dados_resultados.csv?raw=true')
dados_resultados.head()
#mecanismos de ação da droga com o alvo
# Out:
#              id  ...  wnt_inhibitor
# 0  id_000644bb2  ...              0
# 1  id_000779bfc  ...              0
# 2  id_000a6266a  ...              0
# 3  id_0015fd391  ...              0
# 4  id_001626bd3  ...              0
#
# [5 rows x 207 columns]

# %%
dados_resultados
# Out:
#                  id  ...  wnt_inhibitor
# 0      id_000644bb2  ...              0
# 1      id_000779bfc  ...              0
# 2      id_000a6266a  ...              0
# 3      id_0015fd391  ...              0
# 4      id_001626bd3  ...              0
# ...             ...  ...            ...
# 23809  id_fffb1ceed  ...              0
# 23810  id_fffb70c0c  ...              0
# 23811  id_fffc1c3f4  ...              0
# 23812  id_fffcb9e7c  ...              0
# 23813  id_ffffdd77b  ...              0
#
# [23814 rows x 207 columns]

# %%
dados_resultados['acat_inhibitor'].unique()
#todos os mecanismos de ação tem resultados com 0(não-ativado) ou 1(ativado)
# Out:
# array([0, 1])

# %%
#mecanismo de ação que foi mais ativado
#int(colunas com números)
#sort é a ordenação
contagem_moa = dados_resultados.select_dtypes('int64').sum().sort_values(ascending=False)
contagem_moa
# Out:
# nfkb_inhibitor                                832
# proteasome_inhibitor                          726
# cyclooxygenase_inhibitor                      435
# dopamine_receptor_antagonist                  424
# serotonin_receptor_antagonist                 404
#                                              ...
# protein_phosphatase_inhibitor                   6
# autotaxin_inhibitor                             6
# diuretic                                        6
# erbb2_inhibitor                                 1
# atp-sensitive_potassium_channel_antagonist      1
# Length: 206, dtype: int64

# %%
dados_resultados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23814 entries, 0 to 23813
# Columns: 207 entries, id to wnt_inhibitor
# dtypes: int64(206), object(1)
# memory usage: 37.6+ MB

# %%
dados_resultados.drop('id', axis=1).sum(axis=1)
# Out:
# 0        1
# 1        0
# 2        3
# 3        0
# 4        1
#         ..
# 23809    1
# 23810    1
# 23811    0
# 23812    1
# 23813    0
# Length: 23814, dtype: int64

# %%
dados_resultados['n_moa']= dados_resultados.drop('id', axis=1).sum(axis=1)

# %%
dados_resultados['ativo_moa']= (dados_resultados['n_moa']!=0)
dados_resultados.head()
# Out:
#              id  5-alpha_reductase_inhibitor  ...  n_moa  ativo_moa
# 0  id_000644bb2                            0  ...      1       True
# 1  id_000779bfc                            0  ...      0      False
# 2  id_000a6266a                            0  ...      3       True
# 3  id_0015fd391                            0  ...      0      False
# 4  id_001626bd3                            0  ...      1       True
#
# [5 rows x 209 columns]

# %%
#mergear dados com merge pandas
dados_combinados=pd.merge(dados, dados_resultados[['id','n_moa', 'ativo_moa']], on= 'id')
dados_combinados
# Out:
#                  id    tratamento  tempo dose  ...    c-98    c-99  n_moa  ativo_moa
# 0      id_000644bb2     com_droga     24   D1  ...  0.3801  0.4176      1       True
# 1      id_000779bfc     com_droga     72   D1  ...  0.6077  0.7371      0      False
# 2      id_000a6266a     com_droga     48   D1  ... -1.4080  0.6931      3       True
# 3      id_0015fd391     com_droga     48   D1  ... -0.3876 -0.8154      0      False
# 4      id_001626bd3     com_droga     72   D2  ... -0.3786  0.7125      1       True
# ...             ...           ...    ...  ...  ...     ...     ...    ...        ...
# 23809  id_fffb1ceed     com_droga     24   D2  ...  0.5258  0.4680      1       True
# 23810  id_fffb70c0c     com_droga     24   D2  ... -0.2715  0.3689      1       True
# 23811  id_fffc1c3f4  com_controle     48   D2  ...  0.6656  0.3808      0      False
# 23812  id_fffcb9e7c     com_droga     24   D1  ... -0.6290  0.0740      1       True
# ...

# %%
dados_combinados.query('tratamento=="com_controle"')['ativo_moa'].value_counts()
# Out:
# False    1866
# Name: ativo_moa, dtype: int64

# %%
dados_combinados.query('tratamento=="com_droga"')['ativo_moa'].value_counts()
# Out:
# True     14447
# False     7501
# Name: ativo_moa, dtype: int64

# %%
composto_principal=dados_combinados['composto'].value_counts().index[:11]
plt.figure(figsize=(12,8))
sns.boxplot(data=dados_combinados.query('composto in @composto_principal'), y='g-0', x='composto')

# %%
sns.boxplot(data=dados_combinados.query('composto in @composto_principal'), y='g-0', x='composto', hue='ativo_moa')

# %% [markdown]
# Machine Learning (ultima aula)

# %%
dados_combinados.head()
#ativou ou não algum mecanismo de ação classificando entre true ou false (binária)
# Out:
#              id tratamento  tempo dose  ...    c-98    c-99  n_moa  ativo_moa
# 0  id_000644bb2  com_droga     24   D1  ...  0.3801  0.4176      1       True
# 1  id_000779bfc  com_droga     72   D1  ...  0.6077  0.7371      0      False
# 2  id_000a6266a  com_droga     48   D1  ... -1.4080  0.6931      3       True
# 3  id_0015fd391  com_droga     48   D1  ... -0.3876 -0.8154      0      False
# 4  id_001626bd3  com_droga     72   D2  ... -0.3786  0.7125      1       True
#
# [5 rows x 879 columns]

# %%
dados_resultados.head()
# Out:
#              id  5-alpha_reductase_inhibitor  ...  n_moa  ativo_moa
# 0  id_000644bb2                            0  ...      1       True
# 1  id_000779bfc                            0  ...      0      False
# 2  id_000a6266a                            0  ...      3       True
# 3  id_0015fd391                            0  ...      0      False
# 4  id_001626bd3                            0  ...      1       True
#
# [5 rows x 209 columns]

# %% [markdown]
# Que modelos de MACHINE LEARNING iremos implementar?

# %%
#biblioteca scikit-learn, problemas para resolver
#escolher modelo de classificação, Regressão logística (linear models) 
#já tem bbc no colab, no jupýter tem que instalar

from sklearn.linear_model import LogisticRegression
# verificação da qualidade do modelo como está perfomando
from sklearn.model_selection import train_test_split

x= dados_combinados.select_dtypes('float64')
y= dados_combinados['ativo_moa']
# está retornando 4 conjunto de dados para o teste do modelo com variaveis que não foram vistas
#tamanhos dos dados de teste, falar a prporção
x_treino, x_teste, y_treino, y_teste = train_test_split(x,y, test_size=0.2, stratify=y, random_state=376)


modelo_rlogistica= LogisticRegression(max_iter=1000)
modelo_rlogistica.fit(x_treino,y_treino)
modelo_rlogistica.score(x_teste,y_teste)
# Out:
# 0.6264959059416334

# %%
from sklearn.dummy import DummyClassifier
#metódo que calcula a acuracia
from sklearn.metrics import accuracy_score


modelo_dummy = DummyClassifier('most_frequent')
modelo_dummy.fit(x_treino, y_treino)
#previsão do modelo
previsao_dummy=modelo_dummy.predict(x_teste)
accuracy_score(y_teste, previsao_dummy)
# Out:
# 0.6067604450976275

# %%
dados_combinados['ativo_moa'].value_counts(normalize=True)
# Out:
# True     0.60666
# False    0.39334
# Name: ativo_moa, dtype: float64

# %%
#alguns fatores aleatores fazem o modelo reduzir, o que significa essa proporção? Qual a importância desse dado (como fator biológico)
from sklearn.tree import DecisionTreeClassifier

# teste de outro modelo
x= dados_combinados.select_dtypes('float64')
y= dados_combinados['ativo_moa']
x_treino, x_teste, y_treino, y_teste = train_test_split(x,y, test_size=0.2, stratify=y, random_state=376)

modelo_arvore = DecisionTreeClassifier(max_depth = 3) # maxdepht descreve quantos níveis terão a árvore com o plot
modelo_arvore.fit(x_treino,y_treino)
modelo_arvore.score(x_teste,y_teste)
# Out:
# 0.6105395758975436

# %%
from sklearn import tree


fig , ax = plt.subplots(figsize=(15,10), facecolor='k') #background
tree.plot_tree(modelo_arvore, #modelo do plot
               ax=ax, #figura
               fontsize=10, #tamanho das fontes
               rounded=True,
               filled=True, #graficos coloridos
               feature_names=x_treino.columns,
               class_names=['Não Ativado', 'Ativado'])
plt.show()
#nessa um desses lados seja mais homogeneo possivel, um maior probabilidade de experimentos que não foram ativos
# o ultimo nivel são as folhas que reaizam a classificação (decisão da árvore) - ativo ou não-ativo
#

# %%
from sklearn.tree import DecisionTreeClassifier

# teste de outro modelo
x= dados_combinados.select_dtypes('float64')
y= dados_combinados['ativo_moa']
x_treino, x_teste, y_treino, y_teste = train_test_split(x,y, test_size=0.2, stratify=y, random_state=376)

teste=[]
treino=[]
for i in range(1,15):
  modelo_arvore = DecisionTreeClassifier(max_depth = i)
  modelo_arvore.fit(x_treino,y_treino)
  teste.append(modelo_arvore.score(x_teste,y_teste))
  treino.append(modelo_arvore.score(x_treino,y_treino))

# %%
teste
# Out:
# [0.6067604450976275,
#  0.6067604450976275,
#  0.6105395758975436,
#  0.6199874028973336,
#  0.62019735460844,
#  0.6185177409195884,
#  0.6208272097417594,
#  0.62019735460844,
#  0.6159983203863112,
#  0.6138988032752467,
#  0.6115893344530758,
#  0.5968927146756247,
#  0.5985723283644762,
#  0.5964728112534117]

# %%
treino
# Out:
# [0.6066348223190384,
#  0.6066348223190384,
#  0.6211222508004829,
#  0.6360820954280615,
#  0.6412261823526324,
#  0.6489423127394888,
#  0.6605427536612252,
#  0.6707259461445594,
#  0.689570101307018,
#  0.706892026665267,
#  0.7293055482651829,
#  0.7530838276205973,
#  0.7769670883418194,
#  0.7992756285759278]

# %%
sns.lineplot(x=range(1,15), y=teste, label='teste')
sns.lineplot(x=range(1,15), y=treino, label='treino')
#mais profundidade da arvore, melhor de prever o comportamento dos resultados de treino,  e mais falha no teste
#precisa de outras estratégias de decisão de max_depht menor
#modelo de randomforest

# %%
#dizer quando tem ou não drogas
pd.get_dummies(dados_combinados['tratamento'])
# Out:
#        com_controle  com_droga
# 0                 0          1
# 1                 0          1
# 2                 0          1
# 3                 0          1
# 4                 0          1
# ...             ...        ...
# 23809             0          1
# 23810             0          1
# 23811             1          0
# 23812             0          1
# 23813             0          1
#
# [23814 rows x 2 columns]

# %%
pd.get_dummies(dados_combinados, columns=['tratamento', 'dose', 'tempo' ])
# Out:
#                  id   composto     g-0  ...  tempo_24  tempo_48  tempo_72
# 0      id_000644bb2  b68db1d53  1.0620  ...         1         0         0
# 1      id_000779bfc  df89a8e5a  0.0743  ...         0         0         1
# 2      id_000a6266a  18bb41b2c  0.6280  ...         0         1         0
# 3      id_0015fd391  8c7f86626 -0.5138  ...         0         1         0
# 4      id_001626bd3  7cbed3131 -0.3254  ...         0         0         1
# ...             ...        ...     ...  ...       ...       ...       ...
# 23809  id_fffb1ceed  df1d0a5a1  0.1394  ...         1         0         0
# 23810  id_fffb70c0c  ecf3b6b74 -1.3260  ...         1         0         0
# 23811  id_fffc1c3f4  cacb2b860  0.3942  ...         0         1         0
# 23812  id_fffcb9e7c  8b87a7a83  0.6660  ...         1         0         0
# 23813  id_ffffdd77b  972f41291 -0.8598  ...         0         0         1
#
# [23814 rows x 883 columns]

# %%
dados_combinados.drop(['id', 'n_moa','composto'], axis=1)
# Out:
#          tratamento  tempo dose     g-0  ...    c-97    c-98    c-99  ativo_moa
# 0         com_droga     24   D1  1.0620  ...  0.2139  0.3801  0.4176       True
# 1         com_droga     72   D1  0.0743  ...  0.1241  0.6077  0.7371      False
# 2         com_droga     48   D1  0.6280  ... -0.2187 -1.4080  0.6931       True
# 3         com_droga     48   D1 -0.5138  ... -0.8784 -0.3876 -0.8154      False
# 4         com_droga     72   D2 -0.3254  ...  0.2885 -0.3786  0.7125       True
# ...             ...    ...  ...     ...  ...     ...     ...     ...        ...
# 23809     com_droga     24   D2  0.1394  ...  0.9171  0.5258  0.4680       True
# 23810     com_droga     24   D2 -1.3260  ... -0.1224 -0.2715  0.3689       True
# 23811  com_controle     48   D2  0.3942  ...  0.7592  0.6656  0.3808      False
# 23812     com_droga     24   D1  0.6660  ...  0.7015 -0.6290  0.0740       True
# 23813     com_droga     72   D1 -0.8598  ... -0.4775 -2.1500 -4.2520      False
#
# ...

# %%
#alguns fatores aleatores fazem o modelo reduzir, o que significa essa proporção? Qual a importância desse dado (como fator biológico)
from sklearn.ensemble import RandomForestClassifier

# teste de outro modelo
x= dados_combinados.drop(['id', 'n_moa','composto'], axis=1) #o que quer tirar
x= pd.get_dummies(x, columns=['tratamento', 'dose', 'tempo' ])
y= dados_combinados['ativo_moa']
x_treino, x_teste, y_treino, y_teste = train_test_split(x,y, test_size=0.2, stratify=y, random_state=376)

modelo_randomforest = RandomForestClassifier() 
modelo_randomforest.fit(x_treino, y_treino)
modelo_randomforest.score(x_teste, y_teste)
# Out:
# 0.9966407726222969
